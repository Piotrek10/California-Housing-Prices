# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import datasets
# %matplotlib inline

# %%
df = datasets.fetch_california_housing(as_frame=True)

# %%
housing_data = df.frame

# %%
housing_data.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
housing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MedInc       20640 non-null  float64
#  1   HouseAge     20640 non-null  float64
#  2   AveRooms     20640 non-null  float64
#  3   AveBedrms    20640 non-null  float64
#  4   Population   20640 non-null  float64
#  5   AveOccup     20640 non-null  float64
#  6   Latitude     20640 non-null  float64
#  7   Longitude    20640 non-null  float64
#  8   MedHouseVal  20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
housing_data.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude   MedHouseVal
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# ...

# %%
housing_data.hist(bins=50, figsize=(20,15))
plt.show()

# %%
f, axes = plt.subplots(1,3,figsize=(20,5))
sns.boxplot(data=housing_data['AveBedrms'], orient='h', ax=axes[0])
axes[0].set_xlabel('AveBedrms')
sns.boxplot(data=housing_data['AveRooms'], orient='h',ax=axes[1])
axes[1].set_xlabel('AveRooms')
sns.boxplot(housing_data['AveOccup'], orient='h', ax=axes[2])
# Out:
# /home/piotrek10/ml/venv/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='AveOccup'>

# %%
housing_data[(housing_data['AveBedrms']>10) | (housing_data['AveRooms']>50) | (housing_data['AveOccup']>200)]
# Out:
#         MedInc  HouseAge    AveRooms  AveBedrms  Population     AveOccup  \
# 1240    3.1250      11.0   47.515152  11.181818        82.0     2.484848
# 1912    4.9750      16.0   56.269231  10.153846        54.0     2.076923
# 1913    4.0714      19.0   61.812500  11.000000       112.0     2.333333
# 1914    1.8750      33.0  141.909091  25.636364        30.0     2.727273
# 1979    4.6250      34.0  132.533333  34.066667        36.0     2.400000
# 2395    3.8750      23.0   50.837838  10.270270        64.0     1.729730
# 3364    5.5179      36.0    5.142857   1.142857      4198.0   599.714286
# 9676    3.2431      14.0   52.848214  11.410714       265.0     2.366071
# 11707   1.1912      22.0   52.690476   8.857143        98.0     2.333333
# 11862   2.6250      25.0   59.875000  15.312500        28.0     1.750000
# 12447   1.6154      17.0   62.422222  14.111111        83.0     1.844444
# 13034   6.1359      52.0    8.275862   1.517241      6675.0   230.172414
# ...

# %%
housing_data = housing_data[~((housing_data['AveBedrms']>10) | (housing_data['AveRooms']>50) | (housing_data['AveOccup']>200))]

# %%
f, axes = plt.subplots(1,3,figsize=(20,5))
sns.boxplot(data=housing_data['AveBedrms'], orient='h', ax=axes[0])
axes[0].set_xlabel('AveBedrms')
sns.boxplot(data=housing_data['AveRooms'], orient='h',ax=axes[1])
axes[1].set_xlabel('AveRooms')
sns.boxplot(housing_data['AveOccup'], orient='h', ax=axes[2])
# Out:
# /home/piotrek10/ml/venv/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='AveOccup'>

# %%
(len(housing_data[housing_data['AveRooms']>30]) / len(housing_data)) * 100
# Out:
# 0.07270612185546023

# %%
housing_data["IncCat"] = np.ceil(housing_data["MedInc"] / 1.5)
# Out:
# /home/piotrek10/ml/venv/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
housing_data["IncCat"].where(housing_data["MedInc"] < 5, 5.0, inplace=True)
# Out:
# /home/piotrek10/ml/venv/lib/python3.6/site-packages/pandas/core/generic.py:9002: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cond, other, inplace, axis, level, errors=errors, try_cast=try_cast

# %%
housing_data["IncCat"].hist()
# Out:
# <AxesSubplot:>

# %%
housing_data["IncCat"].value_counts()/len(housing_data)
# Out:
# 3.0    0.350577
# 2.0    0.318918
# 5.0    0.218462
# 4.0    0.072239
# 1.0    0.039804
# Name: IncCat, dtype: float64

# %%
housing_data['MedHouseVal'] = housing_data['MedHouseVal']*10**5
# Out:
# /home/piotrek10/ml/venv/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
housing_data['MedHouseVal'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
housing_data = housing_data.reset_index(drop=True)

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# %%
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)

# %%
for train_index, test_index in split.split(housing_data, housing_data["IncCat"]):
    strat_train_set = housing_data.loc[train_index]
    strat_test_set = housing_data.loc[test_index]

# %%
strat_train_set["IncCat"].value_counts() / len(strat_train_set)
# Out:
# 3.0    0.350545
# 2.0    0.318909
# 5.0    0.218485
# 4.0    0.072242
# 1.0    0.039818
# Name: IncCat, dtype: float64

# %%
strat_train_set.drop("IncCat" , axis=1, inplace=True)

# %%
strat_test_set.drop("IncCat" , axis=1, inplace=True)

# %%
strat_train_set.head()
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 15315  5.7409      19.0  6.395349   0.939177      1654.0  2.958855     33.19
# 4888   2.3750      48.0  3.600000   0.900000       485.0  4.409091     34.01
# 7942   5.0840      44.0  5.678445   0.957597       799.0  2.823322     33.87
# 8752   8.5491      20.0  6.763699   1.047945       703.0  2.407534     33.81
# 20070  3.1875      13.0  7.216165   1.343985      1486.0  2.793233     38.02
#
#        Longitude  MedHouseVal
# 15315    -117.34     274100.0
# 4888     -118.24     107500.0
# 7942     -118.14     214100.0
# 8752     -118.38     410300.0
# 20070    -120.27      99800.0

# %%
housing_train = strat_train_set.copy()

# %%
housing_train.plot(kind="scatter", x="Longitude", y="Latitude")
plt.show()

# %%
housing_train.plot(kind="scatter", x="Longitude", y="Latitude", alpha=0.1)
plt.show()

# %%
housing_train.plot(kind="scatter", x="Longitude", y="Latitude", alpha=0.4,
                  s=housing_train["Population"]/100, label="Population", figsize=(10,7),
                  c="MedHouseVal", cmap=plt.get_cmap("jet"), colorbar=True)
plt.legend()
plt.show()

# %%
attributes = ['MedInc','HouseAge','AveRooms','MedHouseVal']

# %%
sns.pairplot(housing_train[attributes])

# %%
housing_train.plot(kind='scatter', x='MedInc', y='MedHouseVal', alpha=0.1)
# Out:
# <AxesSubplot:xlabel='MedInc', ylabel='MedHouseVal'>

# %%
sns.heatmap(housing_train[attributes].corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
housing_train['AveOccup'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
housing_train["BedroomsPerRooms"] = housing_train['AveBedrms'] / housing_train['AveRooms']

# %%
corr_matrix = housing_train.corr()

# %%
corr_matrix["MedHouseVal"].sort_values(ascending=False)
# Out:
# MedHouseVal         1.000000
# MedInc              0.688943
# AveRooms            0.199160
# HouseAge            0.107581
# Population         -0.027434
# Longitude          -0.051278
# AveBedrms          -0.074248
# Latitude           -0.139901
# AveOccup           -0.161287
# BedroomsPerRooms   -0.260756
# Name: MedHouseVal, dtype: float64

# %%
housing = strat_train_set.copy()

# %%
housing_labels = housing["MedHouseVal"]

# %%
housing = housing.drop("MedHouseVal", axis=1)

# %%
from sklearn.base import BaseEstimator, TransformerMixin

# %%
housing.columns
# Out:
# Index(['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup',
#        'Latitude', 'Longitude'],
#       dtype='object')

# %%
rooms_ix, bedrooms_ix = 2, 3

# %%
class CombinedAttributesAdder(BaseEstimator, TransformerMixin):
    def __init__(self, add_bedrooms_per_room = True):
        self.add_bedrooms_per_room = add_bedrooms_per_room
    def fit(self, X, y=None):
        return self
    def transform(self, X, y=None):
        if self.add_bedrooms_per_room:
            bedrooms_per_room = X[:, bedrooms_ix] / X[:, rooms_ix]
            return np.c_[X, bedrooms_per_room]
        else:
            return X

# %%
class DataFrameSelector(BaseEstimator, TransformerMixin):
    def __init__(self, attribute_names):
        self.attribute_names = attribute_names
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        return X[self.attribute_names].values

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
num_attribs = list(housing)

# %%
pipeline = Pipeline([
    ('selector', DataFrameSelector(num_attribs)),
    ('attribs_adder', CombinedAttributesAdder()),
    ('std_scaler', StandardScaler())
])

# %%
housing_prepared = pipeline.fit_transform(housing)

# %%
housing_prepared.shape
# Out:
# (16500, 9)

# %%
from sklearn.linear_model import LinearRegression

# %%
lin_reg = LinearRegression()
lin_reg.fit(housing_prepared, housing_labels)
# Out:
# LinearRegression()

# %%
some_data = housing.iloc[:5]

# %%
some_labels = housing_labels.iloc[:5]

# %%
some_data_prepared = pipeline.transform(some_data)

# %%
print("Prognozy:", lin_reg.predict(some_data_prepared))
# Out:
# Prognozy: [264779.74431328 160253.91678511 273036.99059096 413931.63231956
#   92347.63399382]

# %%
print("Etykiety:", list(some_labels))
# Out:
# Etykiety: [274100.0, 107500.0, 214100.0, 410300.0, 99800.0]

# %%
from sklearn.metrics import mean_squared_error

# %%
housing_preds = lin_reg.predict(housing_prepared)

# %%
lin_mse = mean_squared_error(housing_labels, housing_preds)

# %%
lin_rmse = np.sqrt(lin_mse)

# %%
lin_rmse
# Out:
# 70120.83641535923

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
tree_reg = DecisionTreeRegressor()

# %%
tree_reg.fit(housing_prepared, housing_labels)
# Out:
# DecisionTreeRegressor()

# %%
housing_preds = tree_reg.predict(housing_prepared)

# %%
tree_mse = mean_squared_error(housing_labels, housing_preds)

# %%
tree_rmse = np.sqrt(tree_mse)
tree_rmse
# Out:
# 5.960205403720914e-12

# %%
from sklearn.model_selection import cross_val_score

# %%
scores = cross_val_score(tree_reg, housing_prepared, housing_labels, scoring='neg_mean_squared_error', cv=10)

# %%
tree_rmse_scores = np.sqrt(-scores)

# %%
def display_scores(scores):
    print("Scores:",scores)
    print("Mean:",scores.mean())
    print("Std:",scores.std())

# %%
display_scores(tree_rmse_scores)
# Out:
# Scores: [74504.13344432 73260.13272957 73323.90120418 72519.24400255
#  71680.20408462 74690.29529214 74456.88836351 77264.12076599
#  72497.35468134 72076.89993441]
# Mean: 73627.3174502623
# Std: 1572.8899526503565

# %%
lin_scores = cross_val_score(lin_reg, housing_prepared, housing_labels, scoring="neg_mean_squared_error", cv=10)

# %%
lin_rmse_scores = np.sqrt(-lin_scores)

# %%
display_scores(lin_rmse_scores)
# Out:
# Scores: [69265.13630763 69010.64682657 67949.40889238 68861.29141382
#  72194.54848964 72411.60500782 71005.30911176 73559.66178771
#  67949.63278603 72759.01364653]
# Mean: 70496.62542698908
# Std: 2017.0260184174213

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
forest_reg = RandomForestRegressor()

# %%
forest_reg.fit(housing_prepared, housing_labels)
# Out:
# RandomForestRegressor()

# %%
housing_preds = forest_reg.predict(housing_prepared)

# %%
forest_mse = mean_squared_error(housing_labels, housing_preds)

# %%
forest_rmse = np.sqrt(forest_mse)
forest_rmse
# Out:
# 18899.930330491796

# %%
forest_scores = cross_val_score(forest_reg, housing_prepared, housing_labels, scoring="neg_mean_squared_error", cv=10)

# %%
forest_rmse_scores = np.sqrt(-forest_scores)

# %%
display_scores(forest_rmse_scores)
# Out:
# Scores: [50637.50324381 49825.92169758 50737.75458437 52259.69066395
#  47005.18864453 53330.8787086  51489.20655702 52717.90185572
#  49659.65898943 51037.48679377]
# Mean: 50870.11917387853
# Std: 1713.963510141353

# %%
import pickle

# %%
saved_forest_model = pickle.dumps(forest_reg)

# %%
# forest_reg_from_pickle = pickle.loads(saved_forest_model)

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = [
    {'n_estimators': [3,10,30, 100], 'max_features': [2,4,6,8]},
    {'bootstrap': [False], 'n_estimators': [3,10], 'max_features': [2,3,4]}
]

# %%
forest_reg = RandomForestRegressor()

# %%
grid_search = GridSearchCV(forest_reg, param_grid, cv=5, scoring='neg_mean_squared_error')

# %%
grid_search.fit(housing_prepared, housing_labels)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid=[{'max_features': [2, 4, 6, 8],
#                           'n_estimators': [3, 10, 30, 100]},
#                          {'bootstrap': [False], 'max_features': [2, 3, 4],
#                           'n_estimators': [3, 10]}],
#              scoring='neg_mean_squared_error')

# %%
grid_search.best_params_
# Out:
# {'max_features': 4, 'n_estimators': 100}

# %%
final_model = grid_search.best_estimator_

# %%
X_test = strat_test_set.drop('MedHouseVal', axis=1)
y_test = strat_test_set['MedHouseVal'].copy()

# %%
X_test_prepared = pipeline.transform(X_test)

# %%
final_preds = final_model.predict(X_test_prepared)

# %%
final_mse = mean_squared_error(y_test, final_preds)
final_lmse = np.sqrt(final_mse)
final_lmse
# Out:
# 49254.57308162917
